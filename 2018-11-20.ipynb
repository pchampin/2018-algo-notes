# %%
# exercice 1

def somme_impairs(N):
    """
    :entrée N: int
    :pré-cond: N ≥ 0
    :sortie s: int
    :post-cond: s est la somme des N premiers entiers impairs
    """
    s = 0
    i = 1 # valeur du prochain nombre à ajouter
    while i<=2*N-1:
        s = s + i
        i = i+2
    return s

def somme_impairs(N):
    s = 0
    i = 1  # position du prochain nombre à ajouter
    while i <= N:
        s = s + 2*i-1
        i = i+1
    return s

def somme_impairs(N):
    # N est le nombre d'entiers impairs qu'il nous reste à ajouter
    s = 0
    i = 1
    while N > 0:
        s = s+i
        i = i+2
        N = N-1
    return s

def somme_impairs(N):
    return N*N

print(somme_impairs(1))
print(somme_impairs(2))
print(somme_impairs(3))        
print(somme_impairs(4))
# Out:
# 1
# 4
# 9
# 16

# %%
def syracuse(N):
    e = 0
    while N > 1:
        if N % 2 != 0:
            N = 3*N+1
            e = e+1
        else:
            N = N//2
            e = e+1
    return e

def syracuse(N):
    e = 0
    while N > 1:
        if N % 2 != 0:
            N = 3*N+1
            e = e+1
            # 3*N+1 est forcément pair, donc:
        N = N//2
        e = e+1
    return e

# %%
# Ex4

def moyennes(N):
    """
    :entrée N: int
    :pré-cond: N > 0
    :sortie mh, mf: float
    :post-cond:
        mh est l'age moyen des garçons, -1 s'il n'y en a pas
        mf est l'age moyen des fille,   -1 s'il n'y en a pas
    """
    nh = 0 # nombre d'hommes
    nf = 0 # nombre de femmes
    sh = 0 # somme des ages des hommes
    sf = 0 # somme des ages des femmes
    i = 1
    while i < N:
        if sexe(i) == 1: # c'est un garçon !
            nh = nh + 1
            sh = sh + age(i)
        if sexe(i) == 2: # c'est une fille !
            nf = nf + 1
            sf = sf + age(i)            
        i = i+1
    if nh > 0:
        mh = sh/nh
    else:
        mh = -1
    if nf > 0:
        mf = sf/nf
    else:
        mf = -1
    return mh, mf

# %%
# Ex5

def NiemePremier(N):
    """
    :entrée N: int
    :pré-cond: N > 0
    :sortie p: int
    :post-cond: p est le Nème nombre premier
    """
    i = 1 # nombre de nombres premiers déjà découverts
    n = 2
    p = 2 # le i-ème nombre premier
    while i < N:
        n = n+1
        if premier(n):
            p = n
            i = i+1
    return p

def NiemePremier(N):
    """
    :entrée N: int
    :pré-cond: N > 0
    :sortie p: int
    :post-cond: p est le Nème nombre premier
    """
    n = 2
    p = 2 # le i-ème nombre premier
    # N est le nombre de nombres premiers qui me restent à passer
    while N > 1:
        n = n+1
        if premier(n):
            p = n
            N = N-1
    return p


def NiemePremier(N):
    """
    :entrée N: int
    :pré-cond: N > 0
    :sortie p: int
    :post-cond: p est le Nème nombre premier
    """
    i = 1 # nombre de nombres premiers déjà découverts
    p = 2 # le i-ème nombre premier
    while i < N:
        p = p+1
        while not premier(p):
            p = p+1
        i = i+1
    return p
